# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=6116a6601e48596dece4447cd5ad74f49e60ce2434b9689f1a24983ff8b81bc8
#   Stored in directory: c:\users\zalak\appdata\local\pip\cache\wheels\f8\e0\3d\9d0c2020c44a519b9f02ab4fa6d2a4a996c98d79ab2f569fa1
# Successfully built sklearn
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("DV_Data_Final.xlsx")

# %%
df1 = df.sort_values(by=['Name','Startdatetime'])
df1
# Out:
#                  Startdatetime Aqi Param  Aqi Value    Co    Co 2  Light  \
# 381    2019-01-01 15:14:59.999       NaN        NaN  2.63  412.70    3.0
# 386    2019-01-01 15:30:00.000       NaN        NaN  2.60  407.96    3.0
# 391    2019-01-01 15:45:00.000       NaN        NaN  2.81  418.74    3.0
# 396    2019-01-01 15:59:59.999       NaN        NaN  3.01  427.32    3.0
# 401    2019-01-01 16:15:00.000       NaN        NaN  3.22  451.20    3.0
# ...                        ...       ...        ...   ...     ...    ...
# 327424 2020-10-24 11:16:14.000      pm10      136.0  0.27  230.90  374.9
# 327432 2020-10-24 11:34:22.999      pm10      117.0  0.34  254.20  177.9
# 327440 2020-10-24 11:52:34.000      pm10      137.0  0.39  258.90   48.9
# 327448 2020-10-24 12:10:46.000      pm10      137.0  0.41  260.40   46.3
# 327456 2020-10-24 12:28:54.999      pm10      137.0  0.41  260.60   31.2
#
#                   Name  Noise   No 2    O 3  ...               Remark     Rh  \
# ...

# %%
sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
print(df1.isnull().sum())
# Out:
# Startdatetime           0
# Aqi Param           81333
# Aqi Value           81333
# Co                      0
# Co 2                    0
# Light                   0
# Name                    0
# Noise                   0
# No 2                    0
# O 3                     0
# Pm 10                   0
# Pm 25                   0
# Remark              81333
# Rh                      0
# So 2                16618
# Temp                    0
# Uva                     0
# Uvb                     0
# location_lat            0
# location_long           0
# location_address        0
# dtype: int64

# %%
(df1.isnull().sum()/df1.shape[0]*100).sort_values(ascending=False)
# Out:
# Remark              24.837613
# Aqi Value           24.837613
# Aqi Param           24.837613
# So 2                 5.074834
# Startdatetime        0.000000
# location_long        0.000000
# location_lat         0.000000
# Uvb                  0.000000
# Uva                  0.000000
# Temp                 0.000000
# Rh                   0.000000
# Pm 10                0.000000
# Pm 25                0.000000
# O 3                  0.000000
# No 2                 0.000000
# Noise                0.000000
# Name                 0.000000
# Light                0.000000
# Co 2                 0.000000
# Co                   0.000000
# location_address     0.000000
# dtype: float64

# %%
df.set_index('Startdatetime',inplace=True)

# %%
boxplot = df.boxplot(column=['So 2'])

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(16,5))
plt.subplot(2,2,2)
sns.distplot(df['So 2'])
# Out:
# <AxesSubplot:xlabel='So 2', ylabel='Density'>

# %%
plt.scatter(df.index,df['So 2'])
plt.show()

# %%
print(df1.skew())
# Out:
# Aqi Value        2.096588
# Co               4.050772
# Co 2            -0.336744
# Light            1.505861
# Noise           -1.623806
# No 2             1.026962
# O 3             -2.102341
# Pm 10            5.065706
# Pm 25            2.948485
# Rh              -0.386060
# So 2             4.006581
# Temp            -1.424033
# Uva              5.507299
# Uvb              5.507284
# location_lat     1.578997
# location_long    1.845955
# dtype: float64

# %%
df1['So 2'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['So 2'] = df1['So 2'].replace(0, np.nan)
df1['Co'] = df1['Co'].replace(0, np.nan)
df1['Co 2'] = df1['Co 2'].replace(0, np.nan)
df1['Light'] = df1['Light'].replace(0, np.nan)
df1['Noise'] = df1['Noise'].replace(0, np.nan)
df1['No 2'] = df1['No 2'].replace(0, np.nan)
df1['O 3'] = df1['O 3'].replace(0, np.nan)
df1['Pm 10'] = df1['Pm 10'].replace(0, np.nan)
df1['Pm 25'] = df1['Pm 25'].replace(0, np.nan)
df1['Rh'] = df1['Rh'].replace(0, np.nan)
df1['Temp'] = df1['Temp'].replace(0, np.nan)
df1['Uva'] = df1['Uva'].replace(0, np.nan)
df1['Uvb'] = df1['Uvb'].replace(0, np.nan)
df1
# Out:
#                  Startdatetime Aqi Param  Aqi Value    Co    Co 2  Light  \
# 381    2019-01-01 15:14:59.999       NaN        NaN  2.63  412.70    3.0
# 386    2019-01-01 15:30:00.000       NaN        NaN  2.60  407.96    3.0
# 391    2019-01-01 15:45:00.000       NaN        NaN  2.81  418.74    3.0
# 396    2019-01-01 15:59:59.999       NaN        NaN  3.01  427.32    3.0
# 401    2019-01-01 16:15:00.000       NaN        NaN  3.22  451.20    3.0
# ...                        ...       ...        ...   ...     ...    ...
# 327424 2020-10-24 11:16:14.000      pm10      136.0  0.27  230.90  374.9
# 327432 2020-10-24 11:34:22.999      pm10      117.0  0.34  254.20  177.9
# 327440 2020-10-24 11:52:34.000      pm10      137.0  0.39  258.90   48.9
# 327448 2020-10-24 12:10:46.000      pm10      137.0  0.41  260.40   46.3
# 327456 2020-10-24 12:28:54.999      pm10      137.0  0.41  260.60   31.2
#
#                   Name  Noise   No 2    O 3  ...               Remark     Rh  \
# ...

# %%
print(df1.isnull().sum())
# Out:
# Startdatetime            0
# Aqi Param            81333
# Aqi Value            81333
# Co                    9539
# Co 2                 10598
# Light                11385
# Name                     0
# Noise                 9539
# No 2                 11968
# O 3                   9540
# Pm 10                 9541
# Pm 25                 9541
# Remark               81333
# Rh                   10191
# So 2                 39002
# Temp                  9539
# Ts                  327459
# Uva                 140572
# Uvb                 140571
# location_lat             0
# location_long            0
# location_address         0
# dtype: int64

# %%
(df1.isnull().sum()/df1.shape[0]*100).sort_values(ascending=False)
# Out:
# Ts                  100.000000
# Uva                  42.928122
# Uvb                  42.927817
# Aqi Param            24.837613
# Aqi Value            24.837613
# Remark               24.837613
# So 2                 11.910499
# No 2                  3.654809
# Light                 3.476771
# Co 2                  3.236436
# Rh                    3.112145
# Pm 25                 2.913647
# Pm 10                 2.913647
# O 3                   2.913342
# Noise                 2.913036
# Temp                  2.913036
# Co                    2.913036
# location_lat          0.000000
# location_long         0.000000
# Startdatetime         0.000000
# Name                  0.000000
# location_address      0.000000
# dtype: float64

# %%
sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
boxplot = df1.boxplot(column=['So 2'])

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# Creating distribution
x = df1['So 2']
y = .8 ** x + np.random.randn(10000) + 25

# Creating histogram
fig, axs = plt.subplots(1, 1,
figsize =(10, 7),
tight_layout = True)

axs.hist(x, bins = n_bins)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df1['O 3'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.show()

# %%
plt.scatter(df.index,df['O 3'])
plt.show()

# %%
boxplot = df.boxplot(column=['O 3'])

# %%
import matplotlib.pyplot as plt
plt.hist(df1['Pm 10'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.show()

# %%
plt.scatter(df.index,df['Pm 10'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df1['Pm 25'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.show()

# %%
plt.scatter(df.index,df['Pm 25'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df1['No 2'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.show()

# %%
plt.scatter(df.index,df['No 2'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df1['Co'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.show()

# %%
plt.scatter(df.index,df['Co'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df1['Co 2'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.show()

# %%
plt.scatter(df.index,df['Co 2'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df1['So 2'])
plt.xlabel('Values')
plt.ylabel('frequency')
plt.show()

# %%
plt.scatter(df.index,df['So 2'])
plt.show()
